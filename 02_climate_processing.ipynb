# %% [markdown]
# # Climate data processing (Argentina) — Meteostat
#
# This notebook builds a **monthly climate dataset for Argentina** by:
# - downloading daily temperature metrics from Meteostat for a set of major cities (proxy stations),
# - averaging across cities to obtain a **national proxy** time series,
# - aggregating to **monthly** frequency (YYYY-MM),
# - exporting a clean CSV used downstream by the SQL / DuckDB model.
#
# **Output file**
# - `data/processed/climate_monthly_avg.csv`
#
# **Time period**
# - 2017-01 to 2024-12 (can be adjusted below)

# %% [markdown]
# ## 1. Install and import dependencies

# %%
# !pip install meteostat
# Out:
# Requirement already satisfied: meteostat in c:\users\administrator\anaconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: numpy in c:\users\administrator\anaconda3\lib\site-packages (from meteostat) (1.24.3)
# Requirement already satisfied: pytz in c:\users\administrator\anaconda3\lib\site-packages (from meteostat) (2022.1)
# Requirement already satisfied: pandas>=2 in c:\users\administrator\anaconda3\lib\site-packages (from meteostat) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\administrator\anaconda3\lib\site-packages (from pandas>=2->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrator\anaconda3\lib\site-packages (from pandas>=2->meteostat) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2->meteostat) (1.16.0)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\administrator\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\administrator\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\administrator\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\administrator\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\administrator\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\administrator\anaconda3\lib\site-packages)

# %%
from meteostat import Daily, Point
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## 2. Configure time range and locations

# %%
start = datetime(2017, 1, 1)
end   = datetime(2024, 12, 31)

# %%
cities = {
    "Buenos_Aires": Point(-34.61, -58.38),
    "Cordoba": Point(-31.42, -64.18),
    "Rosario": Point(-32.95, -60.64),
    "Mendoza": Point(-32.89, -68.83),
    "Tucuman": Point(-26.82, -65.22)
}

# %% [markdown]
# ## 3. Download daily data and build a daily national average

# %%
weather_data = []

for city, location in cities.items():
    data = Daily(location, start, end)
    df = data.fetch()
    df["city"] = city
    weather_data.append(df)

# %%
weather_df = pd.concat(weather_data).reset_index()
weather_df.head()
weather_df
# Out:
#             time  tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt    pres  \
# 0     2017-01-01  30.3  27.5  35.0   0.0  <NA>  <NA>  11.1  <NA>  1007.9
# 1     2017-01-02  25.4  21.0  28.0  <NA>  <NA>  <NA>  21.9  <NA>  1011.8
# 2     2017-01-03  25.8  23.7  28.1  <NA>  <NA>  <NA>  14.9  <NA>  1003.8
# 3     2017-01-04  26.2  22.3  31.0  <NA>  <NA>  <NA>   7.0  <NA>  1004.5
# 4     2017-01-05  25.1  19.7  30.8  <NA>  <NA>  <NA>   9.6  <NA>  1011.6
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...     ...
# 14604 2024-12-26  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>    <NA>
# 14605 2024-12-27  25.6  <NA>  33.9  <NA>  <NA>  <NA>  <NA>  <NA>    <NA>
# 14606 2024-12-28  26.2  <NA>  34.0  <NA>  <NA>  <NA>  <NA>  <NA>    <NA>
# 14607 2024-12-29  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>    <NA>
# 14608 2024-12-30  27.6  <NA>  35.7  <NA>  <NA>  <NA>  <NA>  <NA>    <NA>
#
#        tsun          city
# 0      <NA>  Buenos_Aires
# 1      <NA>  Buenos_Aires
# 2      <NA>  Buenos_Aires
# 3      <NA>  Buenos_Aires
# 4      <NA>  Buenos_Aires
# ...     ...           ...
# 14604  <NA>       Tucuman
# 14605  <NA>       Tucuman
# 14606  <NA>       Tucuman
# 14607  <NA>       Tucuman
# 14608  <NA>       Tucuman
#
# [14609 rows x 12 columns]

# %% [markdown]
# ## 4. Aggregate to monthly and export to CSV

# %%
daily_mean = (
    weather_df
    .groupby("time")[["tavg", "tmin", "tmax"]]
    .mean()
    .reset_index()
)

# %%
daily_mean["year_month"] = daily_mean["time"].dt.to_period("M")

monthly_climate = (
    daily_mean
    .groupby("year_month")[["tavg", "tmin", "tmax"]]
    .mean()
    .reset_index()
)

monthly_climate["year_month"] = monthly_climate["year_month"].astype(str)
monthly_climate.head()
# Out:
#   year_month       tavg       tmin       tmax
# 0    2017-01  26.184946   20.79586  32.185108
# 1    2017-02  24.659286  19.932202  30.517798
# 2    2017-03  21.813925  16.893333  27.658602
# 3    2017-04  17.732722  13.462611     24.071
# 4    2017-05   14.76586  10.345538  20.486452

# %%
monthly_climate.to_csv(
    "../data/processed/climate_monthly_avg.csv",
    index=False
)
